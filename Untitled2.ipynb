# %% [markdown]
# <a href="https://colab.research.google.com/github/aditeelwork-lang/IIIT-Python-Course/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list=[]
print(list)
print(type(list))
# Out:
# []
# <class 'list'>

# %%
list=[1,2,3,4]
print(list)
# Out:
# [1, 2, 3, 4]

# %%
string=["aditee","singh","aditya"]
print(string)
# Out:
# ['aditee', 'singh', 'aditya']
